# %%
from config import *
from utils import *
from models import *
from train import *
from inference import *
import pickle
import matplotlib.pyplot as plt
# Out:
# [nltk_data] Error loading punkt: <urlopen error [SSL:
# [nltk_data]     CERTIFICATE_VERIFY_FAILED] certificate verify failed:
# [nltk_data]     unable to get local issuer certificate (_ssl.c:1002)>

# %% [markdown]
# ## 1. Data Preprocessing

# %%
print(device)
# Out:
# cpu

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    pass
else:
    ssl._create_default_https_context = _create_unverified_https_context

nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/ashmitaphuyal/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from datasets import load_dataset

def process_text(text):
    # Tokenize the text into sentences
    sentences = nltk.tokenize.sent_tokenize(text)
    # Prepare to collect pairs
    pairs = []
    # Iterate through the sentences and pair them, ensuring no internal tabs
    for i in range(1, len(sentences)):
        # Replace internal tabs in each sentence to avoid confusion in the output format
        sentence1 = sentences[i-1].replace('\t', ' ')
        sentence2 = sentences[i].replace('\t', ' ')
        pair = f"{sentence1}\t{sentence2}"
        pairs.append(pair)
    return pairs

def load_huggingface_data(dataset):
   
    # File to save the pairs
    with open('output_pairs.txt', 'w') as file:
        # Process each text entry in the dataset
        for text in dataset['text']:
            # Get pairs from the current text
            pairs = process_text(text)
            # Write each pair to the file
            for pair in pairs:
                file.write(pair + '\n')

dataset = load_dataset("Amirkid/MedQuad-dataset", split='train')
load_huggingface_data(dataset)

# %%
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 32800
# })

# %%
# Define path to new file
datafile = os.path.join(corpus, "output_pairs.txt")

# %%
conversation = read_conversation_from_file(datafile)

# %%
len(conversation)
# Out:
# 159770

# %%
def max_word_count_in_pairs(conversation):
    max_length = 0  # Initialize the maximum length counter
    for index, (question, answer) in enumerate(conversation, start=1):
        # Calculate word count for the question
        question_length = len(question.split())
        # Calculate word count for the answer
        answer_length = len(answer.split())
        
        # Update the maximum word count if the current question or answer has more words
        if question_length > max_length:
            max_length = question_length
        if answer_length > max_length:
            max_length = answer_length

    return max_length

# %%
max_word_count_in_pairs(conversation)
# Out:
# 753

# %%
for index, (question, answer) in enumerate(conversation, start=1):
    print(f"{index}. {question}")
    print(f"   {answer}")
    if index == 10:
        break
# Out:
# 1. Any part of your neck  muscles, bones, joints, tendons, ligaments, or nerves  can cause neck problems.
#    Neck pain is very common.
#
# 2. Neck pain is very common.
#    Pain may also come from your shoulder, jaw, head, or upper arms.
#
# 3. Pain may also come from your shoulder, jaw, head, or upper arms.
#    Muscle strain or tension often causes neck pain.
#
# 4. Muscle strain or tension often causes neck pain.
#    The problem is usually overuse, such as from sitting at a computer for too long.
#
# 5. The problem is usually overuse, such as from sitting at a computer for too long.
#    Sometimes you can strain your neck muscles from sleeping in an awkward position or overdoing it during exercise.
#
# 6. Sometimes you can strain your neck muscles from sleeping in an awkward position or overdoing it during exercise.
#    Falls or accidents, including car accidents, are another common cause of neck pain.
#
# 7. Falls or accidents, including car accidents, are another common cause of neck pain.
#    Whiplash, a soft tissue injury to the neck, is also called neck sprain or strain.
#
# 8. Whiplash, a soft tissue injury to the neck, is also called neck sprain or strain.
#    Treatment depends on the cause, but may include applying ice, taking pain relievers, getting physical therapy or wearing a cervical collar.
#
# 9. Treatment depends on the cause, but may include applying ice, taking pain relievers, getting physical therapy or wearing a cervical collar.
#    You rarely need surgery.
#
# 10. Heel problems are common and can be painful.
#    Often, they result from too much stress on your heel bone and the tissues that surround it.

# %% [markdown]
# ## 2 . Data TOkenization & Batching

# %%
print(corpus)
print(corpus_name)
print(datafile)
print(save_dir)
MAX_LENGTH = 100
print(MAX_LENGTH)
# Out:
# data/MedQuad
# MedQuad
# data/MedQuad/output_pairs.txt
# model
# 100

# %%
def loadPrepareData(corpus, corpus_name, datafile, MAX_LENGTH):
    try:
        print("Start preparing training data ...")
        voc, pairs = readVocs(datafile, corpus_name)
        print("Read {!s} sentence pairs".format(len(pairs)))
        pairs = filterPairs(pairs, MAX_LENGTH)
        print("Trimmed to {!s} sentence pairs".format(len(pairs)))
        print("Counting words...")
        for pair in pairs:
            voc.addSentence(pair[0])
            voc.addSentence(pair[1])
        print("Counted words:", voc.num_words)
        return voc, pairs
    except Exception as e:
        print(f"An error occurred: {e}")
        return None, None

voc, pairs = loadPrepareData(corpus, corpus_name, datafile, MAX_LENGTH)
# Out:
# Start preparing training data ...
# Reading lines...
# Read 159770 sentence pairs
# Trimmed to 158235 sentence pairs
# Counting words...
# Counted words: 29126

# %%
print(voc.word2index.get('to', UNK_token))
print(pairs[0])
# Out:
# 72
# ['any part of your neck muscles bones joints tendons ligaments or nerves can cause neck problems .', 'neck pain is very common .']

# %%
voc_filename = os.path.join( save_dir,'voc.pkl' ) # Name of the file to save the Voc object

# Save the Voc object to a file
with open(voc_filename, 'wb') as voc_file:
    pickle.dump(voc, voc_file)

print(f"Vocabulary object saved to {voc_filename}")
# Out:
# Vocabulary object saved to model/voc.pkl

# %%
# Trim voc and pairs
pairs = trimRareWords(voc, pairs, MIN_COUNT)
# Out:
# Trimmed from 158235 pairs to 158235, 1.0000 of total

# %%
training_pairs, validation_pairs, testing_pairs = split_data(pairs, train_percent=0.90, validation_percent=0.05, test_percent=0.05)
print(f"Training Pairs: {len(training_pairs)}")
print(f"Validation Pairs: {len(validation_pairs)}")
print(f"Testing Pairs: {len(testing_pairs)}")
# Out:
# Training Pairs: 142411
# Validation Pairs: 7911
# Testing Pairs: 7913

# %% [markdown]
# ## 3.  Modeling

# %%
# Initialize models and optimizers
embedding = nn.Embedding(voc.num_words, hidden_size).to(device)
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout).to(device)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc.num_words, decoder_n_layers, dropout).to(device)

# %%
# Initialize optimizers after models are assigned to device
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate_en)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate_de)

if loadFilename:
    checkpoint = torch.load(loadFilename, map_location=device)
    encoder.load_state_dict(checkpoint['en'])
    decoder.load_state_dict(checkpoint['de'])
    encoder_optimizer.load_state_dict(checkpoint['en_opt'])
    decoder_optimizer.load_state_dict(checkpoint['de_opt'])
    embedding.load_state_dict(checkpoint['embedding'])
    voc.__dict__ = checkpoint['voc_dict']

# %% [markdown]
# ## 4. Training

# %%
# Function to load the checkpoint
def load_checkpoint(filepath):
    checkpoint = torch.load(filepath, map_location=torch.device('cpu'))
    return checkpoint

# Load the best model
checkpoint_path = os.path.join(save_dir, model_name, corpus_name, f'best_model_val_per.tar')
checkpoint = load_checkpoint(checkpoint_path)
# print(checkpoint)

#Load Tokenizer
voc1 = Voc(corpus_name)
voc1.__dict__ = checkpoint['voc_dict']

embedding = nn.Embedding(voc1.num_words, hidden_size)
encoder = EncoderRNN(hidden_size, embedding, encoder_n_layers, dropout)
decoder = LuongAttnDecoderRNN(attn_model, embedding, hidden_size, voc1.num_words, decoder_n_layers, dropout)
encoder.load_state_dict(checkpoint['en'])
decoder.load_state_dict(checkpoint['de'])

# Move models to the appropriate device
encoder = encoder.to(device)
decoder = decoder.to(device)

# Ensure models are in evaluation mode
encoder.eval()
decoder.eval()
# Out:
# LuongAttnDecoderRNN(
#   (embedding): Embedding(29126, 512)
#   (embedding_dropout): Dropout(p=0.1, inplace=False)
#   (gru): GRU(512, 512, num_layers=2, dropout=0.1)
#   (concat): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=29126, bias=True)
#   (attn): Attn()
# )

# %% [markdown]
# ## 5. Evaluation

# %%
from rouge_score import rouge_scorer

def calculate_rouge_score(reference, candidate):
    scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
    scores = scorer.score(reference, candidate)
    rouge_score = (scores['rouge1'].fmeasure + scores['rouge2'].fmeasure + scores['rougeL'].fmeasure) / 3
    return rouge_score

def calculate_precision_recall_f1(reference, candidate):
    true_positives = len(set(reference) & set(candidate))
    precision = true_positives / len(candidate) if len(candidate) > 0 else 0
    recall = true_positives / len(reference) if len(reference) > 0 else 0
    f1_score = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    return precision, recall, f1_score

# Assuming 'conversation' is defined and 'searcher', 'voc' are properly initialized
eval_conversations = testing_pairs  

total_bleu_score = 0
total_rouge_score = 0
total_precision = 0
total_recall = 0
total_f1_score = 0

for i, (question, actual_answer) in enumerate(eval_conversations, start=1):
    generated_response = evaluate(encoder, decoder, question, voc, PAD_token, SOS_token, UNK_token, EOS_token, device, max_length=100)
    
    # Calculate BLEU score
    bleu_score = calculate_bleu_score([actual_answer], generated_response)
    total_bleu_score += bleu_score
    
    # Calculate ROUGE score
    reference_corpus = " ".join(actual_answer)  # Flatten the nested list into a single string
    candidate_corpus = " ".join(generated_response)  # Flatten the nested list into a single string
    rouge_score = calculate_rouge_score(reference_corpus, candidate_corpus)
    total_rouge_score += rouge_score
    
    # Calculate precision, recall, and F1 score
    precision, recall, f1_score = calculate_precision_recall_f1(reference_corpus.split(), candidate_corpus.split())
    total_precision += precision
    total_recall += recall
    total_f1_score += f1_score
    
    print(f"----------------------------------------------------------------------------------------------------\n")
    print(f"Q: {question}")
    print(f"Actual Ans: {actual_answer}")
    print(f"Generated Ans: {generated_response}")
    print(f"BLEU Score: {bleu_score}")
    print(f"ROUGE Score: {rouge_score}")
    print(f"Precision: {precision}, Recall: {recall}, F1 Score: {f1_score}\n")

# Calculate averages
average_bleu_score = total_bleu_score / len(eval_conversations)
average_rouge_score = total_rouge_score / len(eval_conversations)
average_precision = total_precision / len(eval_conversations)
average_recall = total_recall / len(eval_conversations)
average_f1_score = total_f1_score / len(eval_conversations)

print(f"Average BLEU Score over {len(eval_conversations)} conversations: {average_bleu_score}")
print(f"Average ROUGE Score over {len(eval_conversations)} conversations: {average_rouge_score}")
print(f"Average Precision over {len(eval_conversations)} conversations: {average_precision}")
print(f"Average Recall over {len(eval_conversations)} conversations: {average_recall}")
print(f"Average F1 Score over {len(eval_conversations)} conversations: {average_f1_score}")
# Out:
# ----------------------------------------------------------------------------------------------------
#
# Q: if cancer is in the subglottis treatment may include the following radiation therapy with or without surgery .
# Actual Ans: surgery alone .
# Generated Ans: the chemotherapy is the the the the the the . . .
# BLEU Score: 9.788429383461836e-232
# ROUGE Score: 0.17084318360914105
# Precision: 0.18421052631578946, Recall: 0.5384615384615384, F1 Score: 0.2745098039215686
#
# ----------------------------------------------------------------------------------------------------
#
# Q: ct scan cat scan a procedure that makes a series of detailed pictures of areas inside the body such as the chest or lymph nodes taken from different angles .
# Actual Ans: the pictures are made by a computer linked to an xray machine .
# Generated Ans: the pictures of a computer linked to a machine
# BLEU Score: 0.2365275810472867
# ROUGE Score: 0.8012684989429175
# Precision: 0.42105263157894735, Recall: 0.3137254901960784, F1 Score: 0.3595505617977528
#
# ----------------------------------------------------------------------------------------------------
#
# Q: some studies have suggested that dietary factors may raise or lower the risk of developing type diabetes .
# Actual Ans: for example breastfed infants and infants receiving vitamin d supplements may have a reduced risk of developing type diabetes while early exposure to cows milk and cereal proteins may increase risk .
# Generated Ans: the risk of risk risk risk risk risk risk risk risk risk risk diabetes diabetes .
# BLEU Score: 2.08481452658178e-155
# ROUGE Score: 0.3165667166416792
# Precision: 0.19696969696969696, Recall: 0.07738095238095238, F1 Score: 0.11111111111111112
#
# ----------------------------------------------------------------------------------------------------
#
# Q: what are the signs and symptoms of scot deficiency ?
# Actual Ans: symptoms of scot deficiency include ketoacidosis crises that are often brought on by physical stress fasting or illness .
# Generated Ans: the human phenotype ontology provides the following list of signs and symptoms for the following .
# BLEU Score: 9.938673559320532e-232
# ROUGE Score: 0.4795747730530339
# Precision: 0.21686746987951808, Recall: 0.17475728155339806, F1 Score: 0.19354838709677422
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the flies are attracted to the motion and dust from moving vehicles .
# Actual Ans: avoid bushes .
# Generated Ans: the the are the the . . . . . . . . . .
# BLEU Score: 9.257324954728539e-232
# ROUGE Score: 0.18162393162393162
# Precision: 0.16, Recall: 0.3333333333333333, F1 Score: 0.21621621621621623
#
# ----------------------------------------------------------------------------------------------------
#
# Q: symptoms symptoms of gum disease may include bad breath that won t go away red or swollen gums tender or bleeding gums painful chewing loose teeth sensitive teeth receding gums or longer appearing teeth bad breath that won t go away red or swollen gums tender or bleeding gums painful chewing loose teeth sensitive teeth receding gums or longer appearing teeth if you have symptoms any of these symptoms may be a sign of a serious problem that should be checked by a dentist .
# Actual Ans: sometimes gum disease has no clear symptoms .
# Generated Ans: the symptoms of symptoms and .
# BLEU Score: 9.918892480173173e-232
# ROUGE Score: 0.4845790497360378
# Precision: 0.48, Recall: 0.3157894736842105, F1 Score: 0.38095238095238093
#
# ----------------------------------------------------------------------------------------------------
#
# Q: if the information is available the table below includes how often the symptom is seen in people with this condition .
# Actual Ans: you can use the medlineplus medical dictionary to look up the definitions for these medical terms .
# Generated Ans: you can use the medlineplus medical dictionary to look up the definitions for these medical terms .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.2289156626506024, Recall: 0.2289156626506024, F1 Score: 0.2289156626506024
#
# ----------------------------------------------------------------------------------------------------
#
# Q: signs and symptoms of the condition generally develop at birth or during early infancy and may include a loss of pain and temperature sensation .
# Actual Ans: because of the inability to feel deep pain affected people suffer repeated severe injuries such as bone fractures and joint injuries that go unnoticed .
# Generated Ans: the features of the and the and and and and
# BLEU Score: 1.4221656316185907e-155
# ROUGE Score: 0.3030587132309856
# Precision: 0.3235294117647059, Recall: 0.0859375, F1 Score: 0.13580246913580246
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the human phenotype ontology provides the following list of signs and symptoms for pulmonary vein stenosis .
# Actual Ans: if the information is available the table below includes how often the symptom is seen in people with this condition .
# Generated Ans: if the information is available the table below includes how often the symptom is seen in people with this condition .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.21428571428571427, Recall: 0.21428571428571427, F1 Score: 0.21428571428571427
#
# ----------------------------------------------------------------------------------------------------
#
# Q: a prosthesis may then be attached to the foot .
# Actual Ans: studies have shown that survival is the same whether the first surgery done is a limbsparing surgery or an amputation .
# Generated Ans: the the the the the the the the . . . . . . .
# BLEU Score: 8.166726842395623e-232
# ROUGE Score: 0.2795081967213115
# Precision: 0.12903225806451613, Recall: 0.04040404040404041, F1 Score: 0.061538461538461535
#
# ----------------------------------------------------------------------------------------------------
#
# Q: melanoma is more likely to spread to nearby tissues and other parts of the body and can be harder to cure .
# Actual Ans: melanoma is easier to cure if the tumor is found before it spreads to the dermis inner layer of skin .
# Generated Ans: the the the the the the the the the the . the
# BLEU Score: 6.085166479973199e-232
# ROUGE Score: 0.24613617376775268
# Precision: 0.11764705882352941, Recall: 0.04878048780487805, F1 Score: 0.06896551724137931
#
# ----------------------------------------------------------------------------------------------------
#
# Q: what are the signs and symptoms of brody myopathy ?
# Actual Ans: symptoms of brody disease typically begin in childhood .
# Generated Ans: the human phenotype ontology provides the following list of signs and symptoms for familial syndrome .
# BLEU Score: 1.1988328686372911e-231
# ROUGE Score: 0.3972144100709789
# Precision: 0.19540229885057472, Recall: 0.3541666666666667, F1 Score: 0.2518518518518518
#
# ----------------------------------------------------------------------------------------------------
#
# Q: some treatments are standard the currently used treatment and some are being tested in clinical trials .
# Actual Ans: a treatment clinical trial is a research study meant to help improve current treatments or obtain information on new treatments for patients with cancer .
# Generated Ans: a clinical trial trial is a new treatment meant to help improve the current treatments .
# BLEU Score: 0.1632020197238171
# ROUGE Score: 0.6356325574806037
# Precision: 0.2328767123287671, Recall: 0.13076923076923078, F1 Score: 0.16748768472906403
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the ninds supports research on genetic disorders such as barth syndrome including basic research on mitochondrial dysfunction and investigations of other inborn errors of metabolism .
# Actual Ans: scientists have identified many of the genetic mutations that cause mitochondrial diseases and have created animal models which can be used to investigate potential treatments .
# Generated Ans: the and the and the and the and the and . .
# BLEU Score: 4.0115889851321486e-232
# ROUGE Score: 0.2509954010926263
# Precision: 0.21875, Recall: 0.046052631578947366, F1 Score: 0.07608695652173914
#
# ----------------------------------------------------------------------------------------------------
#
# Q: if most of your fat is around your waist rather than at your hips youre at a higher risk for heart disease and type diabetes .
# Actual Ans: this risk may be higher with a waist size that is greater than inches for women or greater than inches for men .
# Generated Ans: for women who have diabetes may be at risk for chd .
# BLEU Score: 3.403748529681641e-155
# ROUGE Score: 0.4256444688599971
# Precision: 0.4146341463414634, Recall: 0.18888888888888888, F1 Score: 0.25954198473282447
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the first number of the fraction is how many people had the symptom and the second number is the total number of people who were examined in one study .
# Actual Ans: for example a frequency of means that in a study of people all patients were found to have that symptom .
# Generated Ans: for example a frequency of means that in a study of people all patients were found to have that symptom .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.25882352941176473, Recall: 0.25882352941176473, F1 Score: 0.25882352941176473
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# Actual Ans: the frequency may also be listed as a fraction .
# Generated Ans: the frequency may also be listed as a fraction .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.48717948717948717, Recall: 0.48717948717948717, F1 Score: 0.48717948717948717
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the esophagus is a hollow tube that carries food and liquids from your throat to your stomach .
# Actual Ans: early esophageal cancer usually does not cause symptoms .
# Generated Ans: the the is the the the the the .
# BLEU Score: 1.0518351895246305e-231
# ROUGE Score: 0.18779342723004697
# Precision: 0.20833333333333334, Recall: 0.10204081632653061, F1 Score: 0.136986301369863
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# Actual Ans: the frequency may also be listed as a fraction .
# Generated Ans: the frequency may also be listed as a fraction .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.48717948717948717, Recall: 0.48717948717948717, F1 Score: 0.48717948717948717
#
# ----------------------------------------------------------------------------------------------------
#
# Q: to diagnose acute bronchitis your health care provider will ask about your symptoms and listen to your breathing .
# Actual Ans: you may also have other tests .
# Generated Ans: the doctor may the the the the and . the .
# BLEU Score: 1.1896457329133973e-231
# ROUGE Score: 0.38461538461538464
# Precision: 0.28125, Recall: 0.36, F1 Score: 0.3157894736842105
#
# ----------------------------------------------------------------------------------------------------
#
# Q: lymphoproliferative disorders are often treated like cancer .
# Actual Ans: true histiocytic lymphoma .
# Generated Ans: the the the the the . . . . .
# BLEU Score: 1.0244914152188952e-231
# ROUGE Score: 0.2105263157894737
# Precision: 0.2, Recall: 0.16666666666666666, F1 Score: 0.1818181818181818
#
# ----------------------------------------------------------------------------------------------------
#
# Q: fatigue shortness of breath dizziness and a fast or irregular heartbeat caused by anemia .
# Actual Ans: gtd sometimes causes an overactive thyroid .
# Generated Ans: the the the the walls walls walls .
# BLEU Score: 1.0832677820940877e-231
# ROUGE Score: 0.2718413978494624
# Precision: 0.21428571428571427, Recall: 0.15789473684210525, F1 Score: 0.18181818181818182
#
# ----------------------------------------------------------------------------------------------------
#
# Q: other cancers that affect children include brain tumors lymphoma and soft tissue sarcoma .
# Actual Ans: symptoms and treatment depend on the cancer type and how advanced it is .
# Generated Ans: the the the the the the the . . the
# BLEU Score: 8.166726842395623e-232
# ROUGE Score: 0.27348901779959345
# Precision: 0.15384615384615385, Recall: 0.06666666666666667, F1 Score: 0.09302325581395349
#
# ----------------------------------------------------------------------------------------------------
#
# Q: children also may inherit genes from one or both parents that make them more likely to have nighttime ui .
# Actual Ans: slower physical development between the ages of and bedwetting may be the result of a small bladder capacity long sleeping periods and underdevelopment of the bodys alarms that signal a full or emptying bladder .
# Generated Ans: for example a have a of
# BLEU Score: 1.2194411011180272e-233
# ROUGE Score: 0.13019795403215093
# Precision: 0.5555555555555556, Recall: 0.056179775280898875, F1 Score: 0.1020408163265306
#
# ----------------------------------------------------------------------------------------------------
#
# Q: a genetic disorder can also occur through a spontaneous gene mutation meaning neither parent carries a copy of the mutated gene .
# Actual Ans: once a spontaneous gene mutation has occurred in a person it can be passed to the person s children .
# Generated Ans: a condition in the affected person has a person s child s lifetime .
# BLEU Score: 5.449369898725428e-155
# ROUGE Score: 0.5703518054395247
# Precision: 0.2727272727272727, Recall: 0.18292682926829268, F1 Score: 0.218978102189781
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the skin tissue is examined in a lab by a pathologista doctor who specializes in diagnosing diseases .
# Actual Ans: a kidney biopsy may also be needed .
# Generated Ans: the the the the the the
# BLEU Score: 0
# ROUGE Score: 0.14492753623188406
# Precision: 0.05555555555555555, Recall: 0.034482758620689655, F1 Score: 0.0425531914893617
#
# ----------------------------------------------------------------------------------------------------
#
# Q: some medical centers will consider patients older than for lung transplants if they have no other serious medical problems .
# Actual Ans: the major complications of a lung transplant are rejection and infection .
# Generated Ans: if you have be the the to . . . .
# BLEU Score: 1.0862663708453601e-231
# ROUGE Score: 0.22263895400322964
# Precision: 0.391304347826087, Recall: 0.14285714285714285, F1 Score: 0.20930232558139536
#
# ----------------------------------------------------------------------------------------------------
#
# Q: this condition typically causes difficulty with grasping movements or using a pen or pencil .
# Actual Ans: people with partington syndrome may also have dystonia affecting other parts of the body dystonia affecting the muscles in the face and those involved in speech may cause impaired speech dysarthria .
# Generated Ans: the the of the the the the . . .
# BLEU Score: 8.024282857447962e-156
# ROUGE Score: 0.18944934239051883
# Precision: 0.2608695652173913, Recall: 0.03571428571428571, F1 Score: 0.06282722513089005
#
# ----------------------------------------------------------------------------------------------------
#
# Q: patients who take part in a clinical trial may receive the standard treatment or be among the first to receive a new treatment .
# Actual Ans: patients who take part in clinical trials also help improve the way cancer will be treated in the future .
# Generated Ans: patients who take part in clinical trials also help improve the way cancer will be treated in the future .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.25287356321839083, Recall: 0.25287356321839083, F1 Score: 0.25287356321839083
#
# ----------------------------------------------------------------------------------------------------
#
# Q: hemoglobin is the protein in red blood cells that carries oxygen to cells throughout the body .
# Actual Ans: in people with the characteristic features of alpha thalassemia a reduction in the amount of hemoglobin prevents enough oxygen from reaching the body s tissues .
# Generated Ans: the blood cells the blood the the the the the
# BLEU Score: 2.7221839320530296e-232
# ROUGE Score: 0.28520017993702207
# Precision: 0.25, Recall: 0.0661764705882353, F1 Score: 0.10465116279069768
#
# ----------------------------------------------------------------------------------------------------
#
# Q: if the information is available the table below includes how often the symptom is seen in people with this condition .
# Actual Ans: you can use the medlineplus medical dictionary to look up the definitions for these medical terms .
# Generated Ans: you can use the medlineplus medical dictionary to look up the definitions for these medical terms .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.2289156626506024, Recall: 0.2289156626506024, F1 Score: 0.2289156626506024
#
# ----------------------------------------------------------------------------------------------------
#
# Q: a change in air pressure or a very sudden deep breath may cause a rupture to occur .
# Actual Ans: in most cases there are no prior signs of illness .
# Generated Ans: a blood of the . . . . . . . .
# BLEU Score: 1.1640469867513693e-231
# ROUGE Score: 0.23689475790316128
# Precision: 0.42105263157894735, Recall: 0.1951219512195122, F1 Score: 0.26666666666666666
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# Actual Ans: the frequency may also be listed as a fraction .
# Generated Ans: the frequency may also be listed as a fraction .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.48717948717948717, Recall: 0.48717948717948717, F1 Score: 0.48717948717948717
#
# ----------------------------------------------------------------------------------------------------
#
# Q: affected males have a small head size microcephaly poor muscle tone hypotonia in infancy movement disorders rigidity and seizures .
# Actual Ans: infants with this condition appear normal at birth but then develop severe encephalopathy within the first week of life .
# Generated Ans: the the the the the the the and the . .
# BLEU Score: 5.249111552455261e-232
# ROUGE Score: 0.3030753968253968
# Precision: 0.2413793103448276, Recall: 0.06862745098039216, F1 Score: 0.1068702290076336
#
# ----------------------------------------------------------------------------------------------------
#
# Q: chemotherapy chemotherapy is a cancer treatment that uses drugs to stop the growth of cancer cells either by killing the cells or by stopping them from dividing .
# Actual Ans: when chemotherapy is taken by mouth or injected into a vein or muscle the drugs enter the bloodstream and can reach cancer cells throughout the body systemic chemotherapy .
# Generated Ans: when chemotherapy is taken by mouth or injected into a vein or the body enter the body enter the body systemic chemotherapy .
# BLEU Score: 0.5247800776618617
# ROUGE Score: 0.7747599451303154
# Precision: 0.20388349514563106, Recall: 0.14583333333333334, F1 Score: 0.1700404858299595
#
# ----------------------------------------------------------------------------------------------------
#
# Q: sometimes no information on frequency is available .
# Actual Ans: in these cases the sign or symptom may be rare or common .
# Generated Ans: in these cases the sign or symptom may be rare or common .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.34782608695652173, Recall: 0.34782608695652173, F1 Score: 0.34782608695652173
#
# ----------------------------------------------------------------------------------------------------
#
# Q: some studies also suggest that people affected by weaver syndrome may have an increased risk of developing neuroblastoma .
# Actual Ans: weaver syndrome is usually caused by changes mutations in the ezh gene .
# Generated Ans: the risk of the risk of the the of of .
# BLEU Score: 9.918706012922318e-232
# ROUGE Score: 0.2689204417399144
# Precision: 0.27586206896551724, Recall: 0.13333333333333333, F1 Score: 0.17977528089887643
#
# ----------------------------------------------------------------------------------------------------
#
# Q: when indoors stay in wellscreened or airconditioned areas .
# Actual Ans: keep in mind that sand flies are much smaller than mosquitoes and therefore can get through smaller holes .
# Generated Ans: the the the . . . . . . .
# BLEU Score: 4.165271260927111e-232
# ROUGE Score: 0.15879905950443118
# Precision: 0.25, Recall: 0.0449438202247191, F1 Score: 0.07619047619047618
#
# ----------------------------------------------------------------------------------------------------
#
# Q: for many men the answer is as simple as taking a pill .
# Actual Ans: other men have to try two or three options before they find a treatment that works for them .
# Generated Ans: the the the the the the . . .
# BLEU Score: 3.4625676872110776e-232
# ROUGE Score: 0.320450885668277
# Precision: 0.19047619047619047, Recall: 0.05333333333333334, F1 Score: 0.08333333333333333
#
# ----------------------------------------------------------------------------------------------------
#
# Q: there is no specific treatment for sandhoff disease .
# Actual Ans: supportive treatment includes proper nutrition and hydration and keeping the airway open .
# Generated Ans: the treatment of the the the the the . . . . . . . .
# BLEU Score: 1.1988328686372911e-231
# ROUGE Score: 0.34724238026124815
# Precision: 0.24324324324324326, Recall: 0.11538461538461539, F1 Score: 0.1565217391304348
#
# ----------------------------------------------------------------------------------------------------
#
# Q: weight loss for no known reason .
# Actual Ans: wilms tumor that has spread to the lungs or liver may cause the following signs and symptoms cough .
# Generated Ans: for more information about physical activity and physical activity .
# BLEU Score: 4.95337021941109e-232
# ROUGE Score: 0.39913178945894384
# Precision: 0.3220338983050847, Recall: 0.23170731707317074, F1 Score: 0.2695035460992908
#
# ----------------------------------------------------------------------------------------------------
#
# Q: eating more protein than the body needs may burden the kidneys and cause kidney function to decline faster .
# Actual Ans: however protein intake that is too low may lead to malnutrition a condition that occurs when the body does not get enough nutrients .
# Generated Ans: the blood the the the the the the the . . . .
# BLEU Score: 4.895533628427548e-232
# ROUGE Score: 0.29553850525717534
# Precision: 0.24242424242424243, Recall: 0.07272727272727272, F1 Score: 0.11188811188811186
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the first number of the fraction is how many people had the symptom and the second number is the total number of people who were examined in one study .
# Actual Ans: for example a frequency of means that in a study of people all patients were found to have that symptom .
# Generated Ans: for example a frequency of means that in a study of people all patients were found to have that symptom .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.25882352941176473, Recall: 0.25882352941176473, F1 Score: 0.25882352941176473
#
# ----------------------------------------------------------------------------------------------------
#
# Q: treatment options for retinoblastoma treatment of unilateral bilateral and cavitary retinoblastoma if it is likely that the eye can be saved treatment may include the following systemic chemotherapy or ophthalmic artery infusion chemotherapy with or without intravitreal chemotherapy to shrink the tumor .
# Actual Ans: this may be followed by one or more of the following cryotherapy .
# Generated Ans: the chemotherapy of the the the the the the the the
# BLEU Score: 4.566872745130659e-155
# ROUGE Score: 0.356768424298489
# Precision: 0.2682926829268293, Recall: 0.2037037037037037, F1 Score: 0.23157894736842105
#
# ----------------------------------------------------------------------------------------------------
#
# Q: for example a frequency of means that in a study of people all patients were found to have that symptom .
# Actual Ans: because these frequencies are based on a specific study the fractions may be different if another group of patients are examined .
# Generated Ans: because these frequencies are based on a specific study the fractions may be different if another group of patients are examined .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.1926605504587156, Recall: 0.1926605504587156, F1 Score: 0.1926605504587156
#
# ----------------------------------------------------------------------------------------------------
#
# Q: or exercise for minutes three times a day .
# Actual Ans: tip you dont need to get your exercise in all at one time .
# Generated Ans: if you your your your .
# BLEU Score: 4.038234320052887e-232
# ROUGE Score: 0.28136200716845877
# Precision: 0.3333333333333333, Recall: 0.13043478260869565, F1 Score: 0.18750000000000003
#
# ----------------------------------------------------------------------------------------------------
#
# Q: people with becker disease often experience temporary attacks of muscle weakness particularly in the arms and hands brought on by movement after periods of rest .
# Actual Ans: they may also develop mild permanent muscle weakness over time .
# Generated Ans: the the of of the and and the and . .
# BLEU Score: 1.0003688322288243e-231
# ROUGE Score: 0.30004498425551057
# Precision: 0.2962962962962963, Recall: 0.14814814814814814, F1 Score: 0.19753086419753085
#
# ----------------------------------------------------------------------------------------------------
#
# Q: one promising area of animal research involves hibernation .
# Actual Ans: the dramatic decrease of blood flow to the brain in hibernating animals is so extensive that it would kill a nonhibernating animal .
# Generated Ans: for more information about the the the
# BLEU Score: 1.354622269514141e-232
# ROUGE Score: 0.3130091671343776
# Precision: 0.375, Recall: 0.10909090909090909, F1 Score: 0.16901408450704225
#
# ----------------------------------------------------------------------------------------------------
#
# Q: people with this condition also have dry scaly skin ichthyosis which is usually present at birth .
# Actual Ans: additional features of this condition include an enlarged liver hepatomegaly clouding of the lens of the eyes cataracts difficulty with coordinating movements ataxia hearing loss short stature muscle weakness myopathy involuntary movement of the eyes nystagmus and mild intellectual disability .
# Generated Ans: the the of of the the the the the the . .
# BLEU Score: 6.144995194088555e-156
# ROUGE Score: 0.16099290780141842
# Precision: 0.2, Recall: 0.023529411764705882, F1 Score: 0.042105263157894736
#
# ----------------------------------------------------------------------------------------------------
#
# Q: kallmann syndrome is estimated to affect in to people and occurs more often in males than in females .
# Actual Ans: kallmann syndrome is the most common form of the disorder .
# Generated Ans: the is is the the the the the . of
# BLEU Score: 6.552765724042392e-155
# ROUGE Score: 0.3264550264550265
# Precision: 0.32, Recall: 0.16326530612244897, F1 Score: 0.21621621621621617
#
# ----------------------------------------------------------------------------------------------------
#
# Q: major depression keeps a person from functioning normally .
# Actual Ans: dysthymic disorder or dysthymia is a less severe but sometimes more longlasting form of depression .
# Generated Ans: the can result from the in the . . .
# BLEU Score: 5.622528097505664e-232
# ROUGE Score: 0.2785930584672723
# Precision: 0.5555555555555556, Recall: 0.17647058823529413, F1 Score: 0.26785714285714285
#
# ----------------------------------------------------------------------------------------------------
#
# Q: diverticulosis .
# Actual Ans: many people don t have symptoms but some people have cramping bloating and constipation .
# Generated Ans: the the the the the the the . . .
# BLEU Score: 6.213854539426459e-232
# ROUGE Score: 0.1896245991322392
# Precision: 0.16666666666666666, Recall: 0.05333333333333334, F1 Score: 0.0808080808080808
#
# ----------------------------------------------------------------------------------------------------
#
# Q: your bone marrow is the spongy tissue inside some of your bones such as your hip and thigh bones .
# Actual Ans: it contains immature cells called stem cells .
# Generated Ans: the blood walls of your blood and
# BLEU Score: 0
# ROUGE Score: 0.2782254782254782
# Precision: 0.37037037037037035, Recall: 0.2564102564102564, F1 Score: 0.30303030303030304
#
# ----------------------------------------------------------------------------------------------------
#
# Q: these abnormalities include unusually slow movement bradykinesia muscle rigidity involuntary trembling tremors and an inability to hold the body upright and balanced postural instability .
# Actual Ans: other neurological problems that occur in individuals with mpan include degeneration of the nerve cells that carry visual information from the eyes to the brain optic atrophy which can impair vision problems with speech dysarthria difficulty swallowing dysphagia and in later stages of the condition an inability to control the bowels or the flow of urine incontinence .
# Generated Ans: the features of of syndrome of the the the the . . . . .
# BLEU Score: 3.8610062495935184e-156
# ROUGE Score: 0.17790365776790554
# Precision: 0.3333333333333333, Recall: 0.04472843450479233, F1 Score: 0.07887323943661972
#
# ----------------------------------------------------------------------------------------------------
#
# Q: a very small amount of radioactive material is injected into a vein and travels through the bloodstream .
# Actual Ans: the radioactive material attaches to prostate cancer cells and is detected by a scanner .
# Generated Ans: the radioactive scanner collects the body the the the the
# BLEU Score: 3.865846993487796e-155
# ROUGE Score: 0.5598360655737705
# Precision: 0.3125, Recall: 0.2, F1 Score: 0.24390243902439027
#
# ----------------------------------------------------------------------------------------------------
#
# Q: much of this information comes from orphanet a european rare disease database .
# Actual Ans: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# Generated Ans: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.21359223300970873, Recall: 0.21359223300970873, F1 Score: 0.21359223300970873
#
# ----------------------------------------------------------------------------------------------------
#
# Q: who is at risk for fecal incontinence ?
# Actual Ans: ?
# Generated Ans: ?
# BLEU Score: 1.821831989445342e-231
# ROUGE Score: 0.0
# Precision: 1.0, Recall: 1.0, F1 Score: 1.0
#
# ----------------------------------------------------------------------------------------------------
#
# Q: symptom and symptom severity can vary greatly from person to person .
# Actual Ans: it can be caused by mutations in the eya six or six genes .
# Generated Ans: the and of and and and . and . and . . . . . .
# BLEU Score: 1.0832677820940877e-231
# ROUGE Score: 0.2557932263814617
# Precision: 0.25806451612903225, Recall: 0.17391304347826086, F1 Score: 0.2077922077922078
#
# ----------------------------------------------------------------------------------------------------
#
# Q: among its multiple functions this protein signals immature cells to become bone cells during embryonic development .
# Actual Ans: a mutation in a specific part of the fgfr gene alters the protein and causes prolonged signaling which can promote the premature fusion of bones in the skull hands and feet .
# Generated Ans: the the the the the the the the the the of the
# BLEU Score: 1.2429312220040467e-155
# ROUGE Score: 0.26040355125100884
# Precision: 0.14285714285714285, Recall: 0.03496503496503497, F1 Score: 0.056179775280898875
#
# ----------------------------------------------------------------------------------------------------
#
# Q: if the information is available the table below includes how often the symptom is seen in people with this condition .
# Actual Ans: you can use the medlineplus medical dictionary to look up the definitions for these medical terms .
# Generated Ans: you can use the medlineplus medical dictionary to look up the definitions for these medical terms .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.2289156626506024, Recall: 0.2289156626506024, F1 Score: 0.2289156626506024
#
# ----------------------------------------------------------------------------------------------------
#
# Q: smoking and misuse of certain pain medicines can affect the risk of renal cell cancer .
# Actual Ans: signs of renal cell cancer include blood in the urine and a lump in the abdomen .
# Generated Ans: risk factors and risk factors .
# BLEU Score: 2.213204067596096e-232
# ROUGE Score: 0.2703517155280038
# Precision: 0.4230769230769231, Recall: 0.16923076923076924, F1 Score: 0.24175824175824173
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the top number is called the systolic pressure and represents the pressure as the heart beats and pushes blood through the blood vessels .
# Actual Ans: the bottom number is called the diastolic pressure and represents the pressure as blood vessels relax between heartbeats .
# Generated Ans: the the the the the the the the the the
# BLEU Score: 5.481805263404418e-232
# ROUGE Score: 0.2662763779678203
# Precision: 0.1, Recall: 0.028846153846153848, F1 Score: 0.04477611940298507
#
# ----------------------------------------------------------------------------------------------------
#
# Q: chemotherapy with stem cell transplant stem cell transplant is a method of giving high doses of chemotherapy and sometimes totalbody irradiation and then replacing the bloodforming cells destroyed by the cancer treatment .
# Actual Ans: stem cells immature blood cells are removed from the blood or bone marrow of a donor .
# Generated Ans: the stem stem stem stem stem stem stem cells immature the cells or the the
# BLEU Score: 2.7522306478150186e-78
# ROUGE Score: 0.45164703249303145
# Precision: 0.2, Recall: 0.17142857142857143, F1 Score: 0.18461538461538463
#
# ----------------------------------------------------------------------------------------------------
#
# Q: new types of treatment are being tested in clinical trials .
# Actual Ans: information about clinical trials is available from the nci website treatment for melanoma may cause side effects .
# Generated Ans: this summary section describes treatments that are being studied in clinical trials .
# BLEU Score: 3.781246940543709e-155
# ROUGE Score: 0.5303475888459767
# Precision: 0.2328767123287671, Recall: 0.17346938775510204, F1 Score: 0.19883040935672514
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the first number of the fraction is how many people had the symptom and the second number is the total number of people who were examined in one study .
# Actual Ans: for example a frequency of means that in a study of people all patients were found to have that symptom .
# Generated Ans: for example a frequency of means that in a study of people all patients were found to have that symptom .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.25882352941176473, Recall: 0.25882352941176473, F1 Score: 0.25882352941176473
#
# ----------------------------------------------------------------------------------------------------
#
# Q: this gene provides instructions for making a protein called gmap .
# Actual Ans: this protein plays a critical role in the golgi apparatus a cell structure in which newly produced proteins are modified so they can carry out their functions .
# Generated Ans: this protein is found the of the the the the the
# BLEU Score: 1.2924744808850564e-155
# ROUGE Score: 0.33809523809523806
# Precision: 0.3157894736842105, Recall: 0.09022556390977443, F1 Score: 0.14035087719298245
#
# ----------------------------------------------------------------------------------------------------
#
# Q: both conditions have the same genetic cause and significantly impair movement beginning in childhood however the pattern of nerve degeneration is different .
# Actual Ans: because of their similarities these conditions are sometimes considered the same disorder .
# Generated Ans: the the the the the the the the the the . . . . .
# BLEU Score: 1.1008876702055895e-231
# ROUGE Score: 0.2785930584672723
# Precision: 0.11428571428571428, Recall: 0.05063291139240506, F1 Score: 0.07017543859649122
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the condition is not hereditary .
# Actual Ans: acquired wandering spleen may occur during adulthood due to injuries or other underlying conditions that may weaken the ligaments that hold the spleen .
# Generated Ans: the condition is the the the the the the
# BLEU Score: 2.362550272583459e-232
# ROUGE Score: 0.33022151898734176
# Precision: 0.28125, Recall: 0.06976744186046512, F1 Score: 0.11180124223602485
#
# ----------------------------------------------------------------------------------------------------
#
# Q: some affected individuals have increasing weakness in the muscles that control eye movement leading to droopy eyelids progressive external ophthalmoplegia .
# Actual Ans: most often in tk mds the muscles are the only affected tissues however the liver may be enlarged hepatomegaly seizures can occur and hearing loss caused by nerve damage in the inner ear sensorineural hearing loss may be present .
# Generated Ans: the the of the the the the the the and . .
# BLEU Score: 1.4855833849803955e-232
# ROUGE Score: 0.22375127420998978
# Precision: 0.2903225806451613, Recall: 0.04736842105263158, F1 Score: 0.08144796380090498
#
# ----------------------------------------------------------------------------------------------------
#
# Q: mutations in the fzd lrp and ndp genes can cause familial exudative vitreoretinopathy .
# Actual Ans: these genes provide instructions for making proteins that participate in a chemical signaling pathway that affects the way cells and tissues develop .
# Generated Ans: the gene provides instructions for making a protein called the . . . .
# BLEU Score: 1.7483523075088596e-78
# ROUGE Score: 0.5537661256762381
# Precision: 0.3508771929824561, Recall: 0.15625, F1 Score: 0.2162162162162162
#
# ----------------------------------------------------------------------------------------------------
#
# Q: for example if small cell lung cancer spreads to the brain the cancer cells in the brain are actually lung cancer cells .
# Actual Ans: the disease is metastatic small cell lung cancer not brain cancer .
# Generated Ans: the cancer the the the the the the
# BLEU Score: 7.813508425061864e-232
# ROUGE Score: 0.3186991869918699
# Precision: 0.25925925925925924, Recall: 0.125, F1 Score: 0.1686746987951807
#
# ----------------------------------------------------------------------------------------------------
#
# Q: this condition causes recurrent episodes of pain and joint swelling beginning in infancy or early childhood .
# Actual Ans: these symptoms persist into adulthood although they may improve for short periods .
# Generated Ans: the condition of the the the the the the . .
# BLEU Score: 8.34060433022243e-232
# ROUGE Score: 0.3670588235294117
# Precision: 0.2647058823529412, Recall: 0.1267605633802817, F1 Score: 0.17142857142857143
#
# ----------------------------------------------------------------------------------------------------
#
# Q: second cancers new types of cancer .
# Actual Ans: some late effects may be treated or controlled .
# Generated Ans: the the the the the . . .
# BLEU Score: 9.55980462367717e-232
# ROUGE Score: 0.2597340930674264
# Precision: 0.16666666666666666, Recall: 0.075, F1 Score: 0.10344827586206896
#
# ----------------------------------------------------------------------------------------------------
#
# Q: feeling better after a treatment may take a few hours .
# Actual Ans: home hemodialysis pros you can do the treatment at the times you choose however you should follow your doctors orders about how many times a week you need treatment .
# Generated Ans: the the the the the . .
# BLEU Score: 5.515013042428333e-233
# ROUGE Score: 0.16382950353349035
# Precision: 0.23529411764705882, Recall: 0.029197080291970802, F1 Score: 0.051948051948051945
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the cancer spreads from where it began by getting into the lymph system .
# Actual Ans: the cancer travels through the lymph vessels to other parts of the body .
# Generated Ans: the cancer travels through the lymph system to other parts of the body .
# BLEU Score: 0.7825422900366437
# ROUGE Score: 0.9224328006936702
# Precision: 0.3389830508474576, Recall: 0.3333333333333333, F1 Score: 0.33613445378151263
#
# ----------------------------------------------------------------------------------------------------
#
# Q: treatment will be overseen by a pediatric oncologist a doctor who specializes in treating children with cancer .
# Actual Ans: the pediatric oncologist works with other pediatric health care providers who are experts in treating children with central nervous system cancer and who specialize in certain areas of medicine .
# Generated Ans: the risk of the the .
# BLEU Score: 2.805904574036379e-233
# ROUGE Score: 0.14486059092800666
# Precision: 0.625, Recall: 0.060240963855421686, F1 Score: 0.10989010989010989
#
# ----------------------------------------------------------------------------------------------------
#
# Q: however reports exist of some affected babies living up to five months .
# Actual Ans: those that survive are often mosaic .
# Generated Ans: the the of of the the of of the
# BLEU Score: 0
# ROUGE Score: 0.40547539770625224
# Precision: 0.21739130434782608, Recall: 0.16129032258064516, F1 Score: 0.18518518518518517
#
# ----------------------------------------------------------------------------------------------------
#
# Q: radiation therapy before or after surgery .
# Actual Ans: a clinical trial of targeted therapy histone methyltransferase inhibitor .
# Generated Ans: the radiation therapy the of the the the the . the . .
# BLEU Score: 1.2627076138080564e-231
# ROUGE Score: 0.45499695600628026
# Precision: 0.30952380952380953, Recall: 0.2, F1 Score: 0.2429906542056075
#
# ----------------------------------------------------------------------------------------------------
#
# Q: after other diseases are ruled out a doctor may make a preliminary diagnosis of pls .
# Actual Ans: sometimes doctors wait three to four years before being sure of the diagnosis because early als can look just like pls until additional symptoms surface a few years later .
# Generated Ans: the the the the the the .
# BLEU Score: 4.983376835072531e-233
# ROUGE Score: 0.13776371308016877
# Precision: 0.21052631578947367, Recall: 0.027972027972027972, F1 Score: 0.04938271604938272
#
# ----------------------------------------------------------------------------------------------------
#
# Q: this type of metal is used to make aircrafts and weapons .
# Actual Ans: have had contact with organic dust from birds or hay .
# Generated Ans: the type of cells the the the the
# BLEU Score: 0
# ROUGE Score: 0.24212271973466004
# Precision: 0.3076923076923077, Recall: 0.18181818181818182, F1 Score: 0.2285714285714286
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the human phenotype ontology provides the following list of signs and symptoms for hemophilia b .
# Actual Ans: if the information is available the table below includes how often the symptom is seen in people with this condition .
# Generated Ans: if the information is available the table below includes how often the symptom is seen in people with this condition .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.21428571428571427, Recall: 0.21428571428571427, F1 Score: 0.21428571428571427
#
# ----------------------------------------------------------------------------------------------------
#
# Q: kidney disease .
# Actual Ans: a wide range of kidney diseases can occur in alagille syndrome .
# Generated Ans: the kidney is the the the the the the .
# BLEU Score: 9.97486269044271e-232
# ROUGE Score: 0.27285513361462727
# Precision: 0.26666666666666666, Recall: 0.1509433962264151, F1 Score: 0.19277108433734938
#
# ----------------------------------------------------------------------------------------------------
#
# Q: it is still important to eat foods with less salt .
# Actual Ans: this may help you keep a healthy blood pressure .
# Generated Ans: the the the the the the . .
# BLEU Score: 8.436497969708995e-232
# ROUGE Score: 0.3174906964380649
# Precision: 0.2, Recall: 0.1, F1 Score: 0.13333333333333333
#
# ----------------------------------------------------------------------------------------------------
#
# Q: hcg and ldh may be at any level .
# Actual Ans: poor prognosis for nonseminoma at least one of the following must be true the tumor is in the center of the chest between the lungs or the tumor has spread to organs other than the lungs or the level of any one of the tumor markers is high .
# Generated Ans: the the the the the the the the the . the
# BLEU Score: 5.621731816947045e-233
# ROUGE Score: 0.25896805896805897
# Precision: 0.12903225806451613, Recall: 0.02072538860103627, F1 Score: 0.03571428571428572
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the major characteristics of charge syndrome are more specific to this disorder than are the minor characteristics .
# Actual Ans: many individuals with charge syndrome have a hole in one of the structures of the eye coloboma which forms during early development .
# Generated Ans: the syndrome are the the the the the the . . .
# BLEU Score: 5.53509061105086e-232
# ROUGE Score: 0.34379610999329313
# Precision: 0.34285714285714286, Recall: 0.10810810810810811, F1 Score: 0.16438356164383564
#
# ----------------------------------------------------------------------------------------------------
#
# Q: ehlersdanlos syndrome eds kyphoscoliosis type is caused by changes mutations in the plod gene .
# Actual Ans: this gene encodes an enzyme that helps process molecules which allow collagen to form stable interactions with one another .
# Generated Ans: the gene provides instructions for making a protein called the the .
# BLEU Score: 5.9764165035645784e-232
# ROUGE Score: 0.48908227848101266
# Precision: 0.3157894736842105, Recall: 0.17142857142857143, F1 Score: 0.22222222222222224
#
# ----------------------------------------------------------------------------------------------------
#
# Q: cancer that begins in the colon is called colon cancer and cancer that begins in the rectum is called rectal cancer .
# Actual Ans: cancer that affects either of these organs may also be called colorectal cancer .
# Generated Ans: the cancer is the cancer the the the the
# BLEU Score: 7.176794039009363e-232
# ROUGE Score: 0.45367767017251553
# Precision: 0.28125, Recall: 0.1323529411764706, F1 Score: 0.18000000000000002
#
# ----------------------------------------------------------------------------------------------------
#
# Q: xrays are limited in their capacity to reveal how much joint damage may have occurred in osteoarthritis .
# Actual Ans: xrays usually don t show osteoarthritis damage until there has been a significant loss of cartilage .
# Generated Ans: the the the the the the the the the .
# BLEU Score: 5.087473806581661e-232
# ROUGE Score: 0.2345648400694272
# Precision: 0.14285714285714285, Recall: 0.047058823529411764, F1 Score: 0.07079646017699115
#
# ...
#
# Q: medscape reference s web site offers more specific information on the treatment and management of flc .
# Actual Ans: please click the link to access this resource .
# Generated Ans: please click on the resource resource .
# BLEU Score: 7.8302522937563e-155
# ROUGE Score: 0.7011204481792718
# Precision: 0.45454545454545453, Recall: 0.38461538461538464, F1 Score: 0.41666666666666663
#
# ----------------------------------------------------------------------------------------------------
#
# Q: people with meningovascular syphilis general paresis or tabes dorsalis usually do not return to normal health although they may get much better .
# Actual Ans: individuals who receive treatment many years after they have been infected have a worse prognosis .
# Generated Ans: the the of the the the the the . the . . .
# BLEU Score: 7.617293365989231e-232
# ROUGE Score: 0.2573380205207351
# Precision: 0.2, Recall: 0.07142857142857142, F1 Score: 0.10526315789473682
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# Actual Ans: the frequency may also be listed as a fraction .
# Generated Ans: the frequency may also be listed as a fraction .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.48717948717948717, Recall: 0.48717948717948717, F1 Score: 0.48717948717948717
#
# ----------------------------------------------------------------------------------------------------
#
# Q: you should report any unusual symptoms to a doctor right away .
# Actual Ans: it is important to follow a doctor s instructions when taking any medication .
# Generated Ans: if you have the doctor if you have and the
# BLEU Score: 6.867371326126471e-232
# ROUGE Score: 0.337927292457949
# Precision: 0.3939393939393939, Recall: 0.2, F1 Score: 0.2653061224489796
#
# ----------------------------------------------------------------------------------------------------
#
# Q: even if the surgeon removes all the cancer that can be seen at the time of the surgery some patients may be given chemotherapy or radiation therapy after surgery to kill any cancer cells that are left .
# Actual Ans: treatment given after the surgery to lower the risk that the cancer will come back is called adjuvant therapy .
# Generated Ans: the therapy is given to the the adjuvant the adjuvant adjuvant adjuvant adjuvant adjuvant adjuvant adjuvant
# BLEU Score: 1.1931009847695213e-231
# ROUGE Score: 0.4274371282794433
# Precision: 0.17391304347826086, Recall: 0.17391304347826086, F1 Score: 0.17391304347826086
#
# ----------------------------------------------------------------------------------------------------
#
# Q: women with pof are encouraged to speak to a health care professional .
# Actual Ans: if you wish to obtain more information and support you can visit the international premature ovarian failure association .
# Generated Ans: the of have the the the . . . .
# BLEU Score: 4.95337021941109e-232
# ROUGE Score: 0.16556705326758803
# Precision: 0.36363636363636365, Recall: 0.07692307692307693, F1 Score: 0.126984126984127
#
# ----------------------------------------------------------------------------------------------------
#
# Q: for more indepth information about treatment please visit http www .cdc .gov mmwr preview mmwrhtml rr a .htm other considerations the clinical presentation for anaplasmosis can resemble other tickborne diseases such as rocky mountain spotted fever and ehrlichiosis .
# Actual Ans: similar to anaplasmosis these infections respond well to treatment with doxycycline .
# Generated Ans: the information and to improve the the and . . .
# BLEU Score: 1.0862663708453601e-231
# ROUGE Score: 0.43396226415094336
# Precision: 0.34210526315789475, Recall: 0.17567567567567569, F1 Score: 0.23214285714285715
#
# ----------------------------------------------------------------------------------------------------
#
# Q: it causes your airway to collapse or become blocked during sleep .
# Actual Ans: normal breathing starts again with a snort or choking sound .
# Generated Ans: the the the the the . .
# BLEU Score: 6.325072941044999e-232
# ROUGE Score: 0.19552299552299549
# Precision: 0.23529411764705882, Recall: 0.0784313725490196, F1 Score: 0.11764705882352941
#
# ----------------------------------------------------------------------------------------------------
#
# Q: a small amount of radioactive glucose sugar is injected into a vein .
# Actual Ans: the pet scanner rotates around the body and makes a picture of where glucose is being used in the body .
# Generated Ans: the radioactive scanner rotates the body the body is the
# BLEU Score: 3.5681283547992704e-155
# ROUGE Score: 0.5821314102564102
# Precision: 0.2765957446808511, Recall: 0.15476190476190477, F1 Score: 0.1984732824427481
#
# ----------------------------------------------------------------------------------------------------
#
# Q: utis in men men are less likely than women to have a first uti .
# Actual Ans: but once a man has a uti he is likely to have another .
# Generated Ans: if the risk of a the . . .
# BLEU Score: 7.176794039009363e-232
# ROUGE Score: 0.3474426807760141
# Precision: 0.5555555555555556, Recall: 0.23809523809523808, F1 Score: 0.33333333333333326
#
# ----------------------------------------------------------------------------------------------------
#
# Q: people who use intravenous iv drugs also are at risk for ie because of the germs on needles and syringes .
# Actual Ans: bacteria also may spread to the blood and heart from infections in other parts of the body such as the gut skin or genitals .
# Generated Ans: the is the the the . . . . . . . .
# BLEU Score: 5.390763376891056e-232
# ROUGE Score: 0.2173141186299081
# Precision: 0.2727272727272727, Recall: 0.0594059405940594, F1 Score: 0.09756097560975609
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the higher the level of hdl cholesterol in your blood the lower your chance is of getting heart disease .
# Actual Ans: coronary heart disease is a condition in which plaque plak builds up inside the coronary heart arteries .
# Generated Ans: blood pressure is a higher risk of heart disease and blood pressure .
# BLEU Score: 5.109221451426349e-155
# ROUGE Score: 0.46765527616591446
# Precision: 0.2807017543859649, Recall: 0.18181818181818182, F1 Score: 0.2206896551724138
#
# ----------------------------------------------------------------------------------------------------
#
# Q: most infants with the disorder show significant underdevelopment of part or all of the cerebral hemispheres .
# Actual Ans: the eegs of infants with ohtahara syndrome reveal a characteristic pattern of high voltage spike wave discharge followed by little activity .
# Generated Ans: the the of of the the of . . . .
# BLEU Score: 5.204519837132902e-232
# ROUGE Score: 0.18534739118680724
# Precision: 0.2727272727272727, Recall: 0.05, F1 Score: 0.08450704225352113
#
# ----------------------------------------------------------------------------------------------------
#
# Q: both taeniasis and cysticercosis are most often found in rural areas of developing countries with poor sanitation where pigs roam freely and eat human feces .
# Actual Ans: taeniasis and cysticercosis are rare among persons who live in countries where pigs are not raised and in countries where pigs do not have contact with human feces .
# Generated Ans: the the is the the the the . . . . . . . . . . . . . . . . . . . .
# BLEU Score: 7.421597903312336e-232
# ROUGE Score: 0.196969696969697
# Precision: 0.15, Recall: 0.043795620437956206, F1 Score: 0.06779661016949153
#
# ----------------------------------------------------------------------------------------------------
#
# Q: in most people with gpa inflammation begins in the vessels of the respiratory tract leading to nasal congestion frequent nosebleeds shortness of breath or coughing .
# Actual Ans: severe inflammation in the nose can lead to a hole in the tissue that separates the two nostrils nasal septum perforation or a collapse of the septum causing a sunken bridge of the nose saddle nose .
# Generated Ans: the the the the the the the the the . . . . the
# BLEU Score: 2.8512174185252388e-232
# ROUGE Score: 0.23662280701754387
# Precision: 0.11764705882352941, Recall: 0.024539877300613498, F1 Score: 0.04060913705583757
#
# ----------------------------------------------------------------------------------------------------
#
# Q: biopsy the removal of cells or tissues so they can be viewed under a microscope by a pathologist to check for lch cells .
# Actual Ans: to diagnose lch a biopsy of bone lesions skin lymph nodes or the liver may be done .
# Generated Ans: the tumor is a the the a the the the the .
# BLEU Score: 7.813508425061864e-232
# ROUGE Score: 0.2504432624113475
# Precision: 0.3225806451612903, Recall: 0.14925373134328357, F1 Score: 0.2040816326530612
#
# ----------------------------------------------------------------------------------------------------
#
# Q: orofaciodigital syndrome ofds type is a genetic condition that was first described in by mohr .
# Actual Ans: ofds type belongs to a group of disorders called orofaciodigital syndromes ofds characterized by mouth malformations unique facial findings and abnormalities of the fingers and or toes .
# Generated Ans: the is of of the and . . .
# BLEU Score: 9.273372099242484e-156
# ROUGE Score: 0.15463836212239013
# Precision: 0.6111111111111112, Recall: 0.06918238993710692, F1 Score: 0.12429378531073446
#
# ----------------------------------------------------------------------------------------------------
#
# Q: instead of i will eat .
# Actual Ans: instead of i will eat .
# Generated Ans: if you have the and . . . . . . . .
# BLEU Score: 9.594503055152632e-232
# ROUGE Score: 0.3347222222222222
# Precision: 0.391304347826087, Recall: 0.5, F1 Score: 0.4390243902439025
#
# ----------------------------------------------------------------------------------------------------
#
# Q: these cases occur in people with no history of the disorder in their family .
# Actual Ans: a person with one of these subtypes has a chance with each pregnancy of passing along the altered gene to his or her child .
# Generated Ans: the is of the the the the the
# BLEU Score: 1.5385710332010157e-232
# ROUGE Score: 0.30423409033034704
# Precision: 0.3181818181818182, Recall: 0.07, F1 Score: 0.11475409836065574
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the cornea helps protect the rest of the eye from germs dust and other harmful matter .
# Actual Ans: the cornea is a highly organized clear structure made up of a group of cells and proteins precisely arranged in layers but it has no blood vessels to nourish or protect it against infection .
# Generated Ans: the the the the the the the the the . . . . . . .
# BLEU Score: 3.3037800743854334e-232
# ROUGE Score: 0.1640551882377804
# Precision: 0.11764705882352941, Recall: 0.025477707006369428, F1 Score: 0.041884816753926704
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the lens may drift further offcenter over time .
# Actual Ans: vision problems are common in isolated ectopia lentis .
# Generated Ans: the the the the the the the the the the .
# BLEU Score: 1.0003688322288243e-231
# ROUGE Score: 0.14035087719298248
# Precision: 0.0967741935483871, Recall: 0.06382978723404255, F1 Score: 0.07692307692307691
#
# ----------------------------------------------------------------------------------------------------
#
# Q: for example a frequency of means that in a study of people all patients were found to have that symptom .
# Actual Ans: because these frequencies are based on a specific study the fractions may be different if another group of patients are examined .
# Generated Ans: because these frequencies are based on a specific study the fractions may be different if another group of patients are examined .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.1926605504587156, Recall: 0.1926605504587156, F1 Score: 0.1926605504587156
#
# ----------------------------------------------------------------------------------------------------
#
# Q: low levels of gh in adults some people who received pituitary hgh as children may have low levels of gh as adults and might therefore benefit from bgh as adults .
# Actual Ans: people with low levels of growth hormone as adults may have symptoms or changes like these more body fat less muscle less bone mass less strength less energy if you lacked gh as a child and have these problems as an adult ask your doctor whether they might be due to low gh .
# Generated Ans: the risk of to the to . . . .
# BLEU Score: 1.6553617538550678e-233
# ROUGE Score: 0.11556991950204987
# Precision: 0.5, Recall: 0.04504504504504504, F1 Score: 0.08264462809917356
#
# ----------------------------------------------------------------------------------------------------
#
# Q: an orthodontist specializes in correcting teeth or jaw problems .
# Actual Ans: the mouthpiece will adjust your lower jaw and your tongue to help keep your airways open while you sleep .
# Generated Ans: the the the the the the . . the .
# BLEU Score: 4.481994719908145e-232
# ROUGE Score: 0.23112297878653018
# Precision: 0.16666666666666666, Recall: 0.04597701149425287, F1 Score: 0.07207207207207207
#
# ----------------------------------------------------------------------------------------------------
#
# Q: teeth that are too crowded .
# Actual Ans: flat feet .
# Generated Ans: the the the the the the . . .
# BLEU Score: 1.0518351895246305e-231
# ROUGE Score: 0.23290598290598288
# Precision: 0.14285714285714285, Recall: 0.3333333333333333, F1 Score: 0.2
#
# ----------------------------------------------------------------------------------------------------
#
# Q: the frequency of a sign or symptom is usually listed as a rough estimate of the percentage of patients who have that feature .
# Actual Ans: the frequency may also be listed as a fraction .
# Generated Ans: the frequency may also be listed as a fraction .
# BLEU Score: 1.0
# ROUGE Score: 1.0
# Precision: 0.48717948717948717, Recall: 0.48717948717948717, F1 Score: 0.48717948717948717
#
# ----------------------------------------------------------------------------------------------------
#
# Q: if the condition is limited to one kidney and the baby has no signs of kidney dysplasia no treatment may be necessary .
# Actual Ans: researchers have not found a way to prevent kidney dysplasia caused by genetic factors or certain genetic syndromes .
# Generated Ans: the is is the the the the the
# BLEU Score: 0
# ROUGE Score: 0.20037664783427492
# Precision: 0.22727272727272727, Recall: 0.050505050505050504, F1 Score: 0.08264462809917354
#
# ----------------------------------------------------------------------------------------------------
#
# Q: hiv the virus that leads to aids can also cause glomerular disease .
# Actual Ans: between and percent of people with hiv experience kidney failure even before developing fullblown aids .
# Generated Ans: the disease can be caused by a buildup of fluid in the brain .
# BLEU Score: 9.709385502639237e-232
# ROUGE Score: 0.3734269827333918
# Precision: 0.3673469387755102, Recall: 0.20224719101123595, F1 Score: 0.26086956521739135
#
# ----------------------------------------------------------------------------------------------------
#
# Q: loss of cells atrophy in certain brain regions is the major cause of the neurological problems seen in people with choreaacanthocytosis .
# Actual Ans: the human phenotype ontology provides the following list of signs and symptoms for choreaacanthocytosis .
# Generated Ans: the condition is the of the the the the .
# BLEU Score: 8.78771736427028e-232
# ROUGE Score: 0.3482186262934926
# Precision: 0.34375, Recall: 0.12087912087912088, F1 Score: 0.17886178861788615
#
# Average BLEU Score over 7913 conversations: 0.18567479506389692
# Average ROUGE Score over 7913 conversations: 0.4169547273446411
# Average Precision over 7913 conversations: 0.26479846826509124
# Average Recall over 7913 conversations: 0.14852382628957708
# Average F1 Score over 7913 conversations: 0.17234573465859787

# %%
import torch

def tensor_from_sentence(voc, sentence, device, UNK_token, EOS_token):
    indexes = [voc.word2index[word] if word in voc.word2index else UNK_token for word in sentence.split()]
    indexes.append(EOS_token)
    
    # Get the length of the tensor
    lengths = torch.tensor([len(indexes)], dtype=torch.long, device=device)
    
    # Convert indexes list to tensor
    tensor = torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)
    
    return tensor, lengths

def evaluate(encoder, decoder, question, voc, PAD_token, SOS_token, UNK_token, EOS_token, device, max_length=100):
    # Preprocess the input question
    processed_question = process_text(question)
    
    # Convert the processed question to a tensor
    input_tensor, input_lengths = tensor_from_sentence(voc, processed_question, device)
    
    # Initialize the decoder input with SOS_token
    decoder_input = torch.tensor([[SOS_token]], device=device)
    
    # Initialize the decoder hidden state with encoder's output
    encoder_outputs, encoder_hidden = encoder(input_tensor, input_lengths)
    decoder_hidden = encoder_hidden[:decoder.n_layers]
    
    # Initialize an empty list to store the generated response
    generated_response = []
    
    # Start generating response tokens
    for _ in range(max_length):
        # Generate a single token
        decoder_output, decoder_hidden = decoder(decoder_input, decoder_hidden, encoder_outputs)
        _, top_index = decoder_output.topk(1)
        generated_token = top_index.squeeze().detach().item()
        
        # Terminate if EOS_token is generated
        if generated_token == EOS_token:
            break
        
        # Append the generated token to the response
        generated_response.append(generated_token)
        
        # Prepare the input for the next iteration
        decoder_input = torch.tensor([[generated_token]], device=device)
    
    # Convert the generated response tokens to words
    generated_response = [voc.index2word[token] for token in generated_response]
    
    # Join the words to form the final response
    generated_response = ' '.join(generated_response)
    
    return generated_response
